# %% [markdown]
# <a href="https://colab.research.google.com/github/hanisdhuzuki/ML-Labwork/blob/main/diabetes_using_deep_learning_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pima Indians Diabetes

# %% [markdown]
# # Breakdown of this notebook:
# 1. **Importing Libraries**
# 2. **Loading the dataset:** Load the data and import the libraries
# 3. **Data Cleaning:** <br>
#  - Deleting redundant columns.
#  - Renaming the columns.
#  - Dropping duplicates.
#  - Cleaning individual columns.
#  - Remove the NaN values from the dataset
#  - Some Transformations
# 3. **Traininig the Model**
# 4. **Generate a Classification Report**

# %% [markdown]
# <h3>Importing Libraries</h3>

# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import keras

print('Python: {}'.format(sys.version))
print('Pandas: {}'.format(pd.__version__))
print('Numpy: {}'.format(np.__version__))
print('Sklearn: {}'.format(sklearn.__version__))
print('Matplotlib: {}'.format(matplotlib.__version__))


import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# Out:
# Python: 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]
# Pandas: 1.4.4
# Numpy: 1.22.4
# Sklearn: 1.2.2
# Matplotlib: 3.7.1

# %% [markdown]
# **Loading the Dataset**

# %%
df=pd.read_csv("diabetes.csv")

# %%
#Describe the dataset
df.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# min       0.000000                  0.078000    21.000000     0.000000
# 25%      27.375000                  0.244000    24.000000     0.000000
# 50%      32.300000                  0.376000    29.000000     0.000000
# 75%      36.800000                  0.624000    40.000000     1.000000
# max      80.600000                  2.420000    81.000000     1.000000

# %% [markdown]
# **DataFrame where the Glucose concentration of a patient is pulled to 0**

# %%
df[df['Glucose'] == 0]
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 20              6        0             68             41        0  39.0
# 75              1        0             48             20        0  24.7
# 182             1        0             74             20       23  27.7
# 342             1        0             68             35        0  32.0
# 349             5        0             80             32        0  41.0
# 502             6        0             68             41        0  39.0
# 812             1        0             68             35        0  32.0
# 819             5        0             80             32        0  41.0
# 972             6        0             68             41        0  39.0
# 1340            1        0             74             20       23  27.7
# 1595            1        0             68             35        0  32.0
# 1602            5        0             80             32        0  41.0
# 1896            1        0             48             20        0  24.7
#
#       DiabetesPedigreeFunction  Age  Outcome
# 20                       0.727   41        1
# 75                       0.140   22        0
# 182                      0.299   21        0
# 342                      0.389   22        0
# 349                      0.346   37        1
# 502                      0.727   41        1
# 812                      0.389   22        0
# 819                      0.346   37        1
# 972                      0.727   41        1
# 1340                     0.299   21        0
# 1595                     0.389   22        0
# 1602                     0.346   37        1
# 1896                     0.140   22        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB

# %% [markdown]
# **Removing the Duplicates**

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 744 entries, 0 to 1568
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               744 non-null    int64
#  1   Glucose                   744 non-null    int64
#  2   BloodPressure             744 non-null    int64
#  3   SkinThickness             744 non-null    int64
#  4   Insulin                   744 non-null    int64
#  5   BMI                       744 non-null    float64
#  6   DiabetesPedigreeFunction  744 non-null    float64
#  7   Age                       744 non-null    int64
#  8   Outcome                   744 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 58.1 KB

# %% [markdown]
# **Preprocess the data, mark zero values as NaN and drop**

# %%
columns = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

for col in columns:
    df[col].replace(0, np.NaN, inplace=True)
    
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   744.000000  739.000000     710.000000     529.000000  385.000000
# mean      3.752688  121.710419      72.261972      29.406427  153.698701
# std       3.335541   30.456331      12.332675      11.137877  112.839569
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.500000      64.000000      22.000000   76.000000
# 50%       3.000000  117.000000      72.000000      29.000000  126.000000
# 75%       6.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000     110.000000  744.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  734.000000                744.000000  744.000000  744.000000
# mean    32.668801                  0.472355   33.142473    0.340054
# std      7.341531                  0.326181   11.751286    0.474046
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.244000   24.000000    0.000000
# 50%     32.400000                  0.375500   29.000000    0.000000
# 75%     36.800000                  0.632500   40.250000    1.000000
# max     80.600000                  2.420000   81.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 744 entries, 0 to 1568
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               744 non-null    int64
#  1   Glucose                   739 non-null    float64
#  2   BloodPressure             710 non-null    float64
#  3   SkinThickness             529 non-null    float64
#  4   Insulin                   385 non-null    float64
#  5   BMI                       734 non-null    float64
#  6   DiabetesPedigreeFunction  744 non-null    float64
#  7   Age                       744 non-null    int64
#  8   Outcome                   744 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 58.1 KB

# %% [markdown]
# **Drop rows with missing values**

# %%
df.dropna(inplace=True)

# summarize the number of rows and columns in df
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   381.000000  381.000000     381.000000     381.000000  381.000000
# mean      3.254593  122.624672      70.708661      29.270341  153.889764
# std       3.169055   30.647801      12.437704      10.630536  113.097366
# min       0.000000   56.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      62.000000      21.000000   76.000000
# 50%       2.000000  119.000000      70.000000      29.000000  126.000000
# 75%       5.000000  143.000000      78.000000      37.000000  190.000000
# max      17.000000  198.000000     110.000000      63.000000  744.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  381.000000                381.000000  381.000000  381.000000
# mean    33.177690                  0.524530   30.787402    0.320210
# std      7.105995                  0.335632   10.140822    0.467171
# min     18.200000                  0.085000   21.000000    0.000000
# 25%     28.400000                  0.282000   23.000000    0.000000
# 50%     33.300000                  0.452000   27.000000    0.000000
# 75%     37.200000                  0.687000   36.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 381 entries, 1 to 1567
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               381 non-null    int64
#  1   Glucose                   381 non-null    float64
#  2   BloodPressure             381 non-null    float64
#  3   SkinThickness             381 non-null    float64
#  4   Insulin                   381 non-null    float64
#  5   BMI                       381 non-null    float64
#  6   DiabetesPedigreeFunction  381 non-null    float64
#  7   Age                       381 non-null    int64
#  8   Outcome                   381 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 29.8 KB

# %% [markdown]
# ## Training the Model

# %% [markdown]
# **Convert dataframe to numpy array**

# %%
dataset = df.values
print(dataset.shape)
# Out:
# (381, 9)

# %% [markdown]
# **Split into input (X) and an output (Y)**

# %%
X = dataset[:,0:8]
Y = dataset[:, 8].astype(int)

# %%
print(X.shape)
print(Y.shape)
print(Y[:5])
# Out:
# (381, 8)
# (381,)
# [0 1 0 0 0]

# %% [markdown]
# **Normalize the data using sklearn StandardScaler**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X)

# %%
print(scaler)
# Out:
# StandardScaler()

# %% [markdown]
# **Transform and display the training data**

# %%
X_standardized = scaler.transform(X)

data = pd.DataFrame(X_standardized)
data.describe()
# Out:
#                   0             1             2             3             4  \
# count  3.810000e+02  3.810000e+02  3.810000e+02  3.810000e+02  3.810000e+02
# mean   7.459766e-17  2.331177e-18  3.893066e-16  1.072341e-16  2.331177e-17
# std    1.001315e+00  1.001315e+00  1.001315e+00  1.001315e+00  1.001315e+00
# min   -1.028342e+00 -2.176739e+00 -3.760347e+00 -2.097695e+00 -1.238523e+00
# 25%   -7.123758e-01 -7.718576e-01 -7.011031e-01 -7.790027e-01 -6.896021e-01
# 50%   -3.964094e-01 -1.184241e-01 -5.705179e-02 -2.546407e-02 -2.469238e-01
# 75%    5.514900e-01  6.656961e-01  5.869995e-01  7.280745e-01  3.197043e-01
# max    4.343087e+00  2.462638e+00  3.163205e+00  3.177075e+00  5.224580e+00
#
#                   5             6             7
# count  3.810000e+02  3.810000e+02  3.810000e+02
# mean  -1.328771e-16  1.142277e-16  1.270491e-16
# std    1.001315e+00  1.001315e+00  1.001315e+00
# min   -2.110526e+00 -1.311281e+00 -9.664179e-01
# 25%   -6.732305e-01 -7.235571e-01 -7.689359e-01
# 50%    1.723482e-02 -2.163843e-01 -3.739718e-01
# 75%    5.667889e-01  4.847075e-01  5.146972e-01
# max    4.780037e+00  5.654887e+00  4.958042e+00

# %% [markdown]
# **Import necessary sklearn and keras packages**

# %%
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# **Do a grid search for the optimal batch size and number of epochs**

# %%
# Define a random seed
seed = 6
np.random.seed(seed)

# Start defining the model
def create_model():
    # create model
    model = Sequential()
    model.add(Dense(8, input_dim = 8, kernel_initializer='normal', activation='relu'))
    model.add(Dense(4, input_dim = 8, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    
    # compile the model
    adam = Adam(lr = 0.01)
    model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
    return model

# create the model
model = KerasClassifier(build_fn = create_model, verbose = 1)

# define the grid search parameters
batch_size = [10, 20, 40]
epochs = [10, 50, 100]

# make a dictionary of the grid search parameters
param_grid = dict(batch_size=batch_size, epochs=epochs)

# build and fit the GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(random_state=None), verbose = 10)
grid_results = grid.fit(X_standardized, Y)

# summarize the results
print("Best: {0}, using {1}".format(grid_results.best_score_, grid_results.best_params_))
means = grid_results.cv_results_['mean_test_score']
stds = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with: {2}'.format(mean, stdev, param))
# Out:
# <ipython-input-21-873d6d5966fe>:19: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model, verbose = 1)
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# Epoch 1/10
# 31/31 [==============================] - 1s 2ms/step - loss: 0.6845 - accuracy: 0.6711
# Epoch 2/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6637 - accuracy: 0.6711
# Epoch 3/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6317 - accuracy: 0.6711
# Epoch 4/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5910 - accuracy: 0.6711
# Epoch 5/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5488 - accuracy: 0.6711
# Epoch 6/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5152 - accuracy: 0.6908
# Epoch 7/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4933 - accuracy: 0.7599
# Epoch 8/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4784 - accuracy: 0.7862
# Epoch 9/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4678 - accuracy: 0.7895
# Epoch 10/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4595 - accuracy: 0.7730
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4485 - accuracy: 0.7922
# [CV 1/5; 1/9] END .....batch_size=10, epochs=10;, score=0.792 total time=   1.7s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/10
# 31/31 [==============================] - 1s 2ms/step - loss: 0.6833 - accuracy: 0.6852
# Epoch 2/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6590 - accuracy: 0.7049
# Epoch 3/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6204 - accuracy: 0.7049
# Epoch 4/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5664 - accuracy: 0.7049
# Epoch 5/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5133 - accuracy: 0.7049
# Epoch 6/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4748 - accuracy: 0.7082
# Epoch 7/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4520 - accuracy: 0.7475
# Epoch 8/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4389 - accuracy: 0.7934
# Epoch 9/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4287 - accuracy: 0.8000
# Epoch 10/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4204 - accuracy: 0.8131
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6041 - accuracy: 0.6711
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 1/9] END .....batch_size=10, epochs=10;, score=0.671 total time=   1.8s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# Epoch 1/10
# 31/31 [==============================] - 1s 2ms/step - loss: 0.6895 - accuracy: 0.6557
# Epoch 2/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6735 - accuracy: 0.6787
# Epoch 3/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6443 - accuracy: 0.6787
# Epoch 4/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5976 - accuracy: 0.6787
# Epoch 5/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5465 - accuracy: 0.6787
# Epoch 6/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5075 - accuracy: 0.6787
# Epoch 7/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4880 - accuracy: 0.6787
# Epoch 8/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4785 - accuracy: 0.6787
# Epoch 9/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4740 - accuracy: 0.6787
# Epoch 10/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4708 - accuracy: 0.6787
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4497 - accuracy: 0.6842
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 1/9] END .....batch_size=10, epochs=10;, score=0.684 total time=   2.9s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# Epoch 1/10
# 31/31 [==============================] - 1s 2ms/step - loss: 0.6897 - accuracy: 0.6885
# Epoch 2/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6834 - accuracy: 0.7377
# Epoch 3/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6756 - accuracy: 0.7639
# Epoch 4/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6667 - accuracy: 0.7672
# Epoch 5/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6572 - accuracy: 0.7607
# Epoch 6/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6482 - accuracy: 0.7508
# Epoch 7/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6399 - accuracy: 0.7574
# Epoch 8/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6329 - accuracy: 0.7574
# Epoch 9/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6262 - accuracy: 0.7607
# Epoch 10/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6206 - accuracy: 0.7672
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6006 - accuracy: 0.8026
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 1/9] END .....batch_size=10, epochs=10;, score=0.803 total time=   2.3s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# Epoch 1/10
# 31/31 [==============================] - 1s 2ms/step - loss: 0.6842 - accuracy: 0.6787
# Epoch 2/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6579 - accuracy: 0.6787
# Epoch 3/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6088 - accuracy: 0.6787
# Epoch 4/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5466 - accuracy: 0.6787
# Epoch 5/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5036 - accuracy: 0.6787
# Epoch 6/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4832 - accuracy: 0.6787
# Epoch 7/10
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4743 - accuracy: 0.6787
# Epoch 8/10
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4686 - accuracy: 0.6787
# Epoch 9/10
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4644 - accuracy: 0.6787
# Epoch 10/10
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4602 - accuracy: 0.6787
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4782 - accuracy: 0.6842
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 1/9] END .....batch_size=10, epochs=10;, score=0.684 total time=   2.0s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# 31/31 [==============================] - 1s 2ms/step - loss: 0.6901 - accuracy: 0.6645
# Epoch 2/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6819 - accuracy: 0.6941
# Epoch 3/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6700 - accuracy: 0.7599
# Epoch 4/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6526 - accuracy: 0.7895
# Epoch 5/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6277 - accuracy: 0.7961
# Epoch 6/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5964 - accuracy: 0.7829
# Epoch 7/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5609 - accuracy: 0.7697
# Epoch 8/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5278 - accuracy: 0.7664
# Epoch 9/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4987 - accuracy: 0.7730
# Epoch 10/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4757 - accuracy: 0.7829
# Epoch 11/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4566 - accuracy: 0.7829
# Epoch 12/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4444 - accuracy: 0.7829
# Epoch 13/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4357 - accuracy: 0.7862
# Epoch 14/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4292 - accuracy: 0.7862
# Epoch 15/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4243 - accuracy: 0.7829
# Epoch 16/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4210 - accuracy: 0.7862
# Epoch 17/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4181 - accuracy: 0.7928
# Epoch 18/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4157 - accuracy: 0.7928
# Epoch 19/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4147 - accuracy: 0.7961
# Epoch 20/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4111 - accuracy: 0.7993
# Epoch 21/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4103 - accuracy: 0.8026
# Epoch 22/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4083 - accuracy: 0.7993
# Epoch 23/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4074 - accuracy: 0.7993
# Epoch 24/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4059 - accuracy: 0.7993
# Epoch 25/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4035 - accuracy: 0.7993
# Epoch 26/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4019 - accuracy: 0.8026
# Epoch 27/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4006 - accuracy: 0.8059
# Epoch 28/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3994 - accuracy: 0.8026
# Epoch 29/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3975 - accuracy: 0.8158
# Epoch 30/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3970 - accuracy: 0.8125
# Epoch 31/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8092
# Epoch 32/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8191
# Epoch 33/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3933 - accuracy: 0.8224
# Epoch 34/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.8257
# Epoch 35/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.8289
# Epoch 36/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3917 - accuracy: 0.8257
# Epoch 37/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3909 - accuracy: 0.8257
# Epoch 38/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3889 - accuracy: 0.8289
# Epoch 39/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3880 - accuracy: 0.8289
# Epoch 40/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3883 - accuracy: 0.8289
# Epoch 41/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3872 - accuracy: 0.8355
# Epoch 42/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3866 - accuracy: 0.8322
# Epoch 43/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3874 - accuracy: 0.8257
# Epoch 44/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3852 - accuracy: 0.8322
# Epoch 45/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3838 - accuracy: 0.8322
# Epoch 46/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3831 - accuracy: 0.8355
# Epoch 47/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3826 - accuracy: 0.8421
# Epoch 48/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3818 - accuracy: 0.8388
# Epoch 49/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3821 - accuracy: 0.8388
# Epoch 50/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3813 - accuracy: 0.8355
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4724 - accuracy: 0.7662
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 2/9] END .....batch_size=10, epochs=50;, score=0.766 total time=   4.9s
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# 31/31 [==============================] - 1s 2ms/step - loss: 0.6840 - accuracy: 0.6984
# Epoch 2/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6638 - accuracy: 0.7049
# Epoch 3/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6300 - accuracy: 0.7049
# Epoch 4/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5783 - accuracy: 0.7049
# Epoch 5/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5202 - accuracy: 0.7049
# Epoch 6/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4792 - accuracy: 0.7311
# Epoch 7/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4545 - accuracy: 0.7934
# Epoch 8/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4405 - accuracy: 0.8066
# Epoch 9/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4308 - accuracy: 0.8131
# Epoch 10/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4238 - accuracy: 0.8066
# Epoch 11/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4170 - accuracy: 0.8131
# Epoch 12/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4118 - accuracy: 0.8131
# Epoch 13/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4062 - accuracy: 0.8033
# Epoch 14/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4018 - accuracy: 0.8131
# Epoch 15/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3972 - accuracy: 0.8164
# Epoch 16/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8197
# Epoch 17/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3905 - accuracy: 0.8197
# Epoch 18/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3872 - accuracy: 0.8197
# Epoch 19/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3849 - accuracy: 0.8164
# Epoch 20/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3826 - accuracy: 0.8197
# Epoch 21/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3804 - accuracy: 0.8164
# Epoch 22/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3781 - accuracy: 0.8230
# Epoch 23/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3775 - accuracy: 0.8262
# Epoch 24/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3742 - accuracy: 0.8197
# Epoch 25/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3731 - accuracy: 0.8262
# Epoch 26/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3716 - accuracy: 0.8230
# Epoch 27/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3703 - accuracy: 0.8197
# Epoch 28/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3689 - accuracy: 0.8230
# Epoch 29/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3676 - accuracy: 0.8197
# Epoch 30/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3665 - accuracy: 0.8197
# Epoch 31/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3653 - accuracy: 0.8197
# Epoch 32/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3641 - accuracy: 0.8197
# Epoch 33/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3633 - accuracy: 0.8295
# Epoch 34/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3620 - accuracy: 0.8262
# Epoch 35/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3611 - accuracy: 0.8164
# Epoch 36/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3599 - accuracy: 0.8197
# Epoch 37/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3591 - accuracy: 0.8197
# Epoch 38/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3582 - accuracy: 0.8197
# Epoch 39/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3579 - accuracy: 0.8262
# Epoch 40/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3559 - accuracy: 0.8262
# Epoch 41/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3555 - accuracy: 0.8262
# Epoch 42/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3547 - accuracy: 0.8262
# Epoch 43/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3541 - accuracy: 0.8328
# Epoch 44/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3525 - accuracy: 0.8328
# Epoch 45/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3509 - accuracy: 0.8361
# Epoch 46/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3502 - accuracy: 0.8328
# Epoch 47/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3487 - accuracy: 0.8328
# Epoch 48/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3477 - accuracy: 0.8328
# Epoch 49/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3465 - accuracy: 0.8361
# Epoch 50/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3450 - accuracy: 0.8361
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7278 - accuracy: 0.6316
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 2/9] END .....batch_size=10, epochs=50;, score=0.632 total time=   6.2s
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# 31/31 [==============================] - 1s 3ms/step - loss: 0.6927 - accuracy: 0.5705
# Epoch 2/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6868 - accuracy: 0.6787
# Epoch 3/50
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6828 - accuracy: 0.6787
# Epoch 4/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6790 - accuracy: 0.6787
# Epoch 5/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6756 - accuracy: 0.6787
# Epoch 6/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6719 - accuracy: 0.6787
# Epoch 7/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6675 - accuracy: 0.6787
# Epoch 8/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6615 - accuracy: 0.6787
# Epoch 9/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6542 - accuracy: 0.7377
# Epoch 10/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6455 - accuracy: 0.7607
# Epoch 11/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6363 - accuracy: 0.7803
# Epoch 12/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6273 - accuracy: 0.7869
# Epoch 13/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6190 - accuracy: 0.7803
# Epoch 14/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6116 - accuracy: 0.7803
# Epoch 15/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6053 - accuracy: 0.7738
# Epoch 16/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5987 - accuracy: 0.7770
# Epoch 17/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5928 - accuracy: 0.7770
# Epoch 18/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5875 - accuracy: 0.7803
# Epoch 19/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5817 - accuracy: 0.7803
# Epoch 20/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5759 - accuracy: 0.7902
# Epoch 21/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5715 - accuracy: 0.7869
# Epoch 22/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5666 - accuracy: 0.7869
# Epoch 23/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5617 - accuracy: 0.7869
# Epoch 24/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5576 - accuracy: 0.7803
# Epoch 25/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5533 - accuracy: 0.7902
# Epoch 26/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5487 - accuracy: 0.7934
# Epoch 27/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5447 - accuracy: 0.7902
# Epoch 28/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5410 - accuracy: 0.7934
# Epoch 29/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5372 - accuracy: 0.8000
# Epoch 30/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5335 - accuracy: 0.7967
# Epoch 31/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5298 - accuracy: 0.7967
# Epoch 32/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5265 - accuracy: 0.8033
# Epoch 33/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5227 - accuracy: 0.8066
# Epoch 34/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5194 - accuracy: 0.8131
# Epoch 35/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5161 - accuracy: 0.8131
# Epoch 36/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5133 - accuracy: 0.8098
# Epoch 37/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5098 - accuracy: 0.8197
# Epoch 38/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5074 - accuracy: 0.8164
# Epoch 39/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.8164
# Epoch 40/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5016 - accuracy: 0.8164
# Epoch 41/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4987 - accuracy: 0.8262
# Epoch 42/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4962 - accuracy: 0.8230
# Epoch 43/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4935 - accuracy: 0.8230
# Epoch 44/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4915 - accuracy: 0.8262
# Epoch 45/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4888 - accuracy: 0.8230
# Epoch 46/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4868 - accuracy: 0.8131
# Epoch 47/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4843 - accuracy: 0.8230
# Epoch 48/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4827 - accuracy: 0.8197
# Epoch 49/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4811 - accuracy: 0.8197
# Epoch 50/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4780 - accuracy: 0.8230
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4653 - accuracy: 0.8158
# [CV 3/5; 2/9] END .....batch_size=10, epochs=50;, score=0.816 total time=   5.0s
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# 31/31 [==============================] - 1s 2ms/step - loss: 0.6902 - accuracy: 0.6525
# Epoch 2/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6804 - accuracy: 0.6656
# Epoch 3/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6671 - accuracy: 0.6656
# Epoch 4/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6463 - accuracy: 0.6656
# Epoch 5/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6176 - accuracy: 0.6656
# Epoch 6/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5856 - accuracy: 0.6656
# Epoch 7/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5547 - accuracy: 0.6885
# Epoch 8/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5292 - accuracy: 0.7377
# Epoch 9/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5088 - accuracy: 0.7803
# Epoch 10/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4964 - accuracy: 0.7770
# Epoch 11/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4841 - accuracy: 0.7770
# Epoch 12/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4764 - accuracy: 0.7672
# Epoch 13/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4701 - accuracy: 0.7639
# Epoch 14/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4650 - accuracy: 0.7639
# Epoch 15/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4610 - accuracy: 0.7672
# Epoch 16/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4578 - accuracy: 0.7639
# Epoch 17/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4549 - accuracy: 0.7639
# Epoch 18/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4533 - accuracy: 0.7639
# Epoch 19/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4501 - accuracy: 0.7639
# Epoch 20/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.7672
# Epoch 21/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4463 - accuracy: 0.7705
# Epoch 22/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4452 - accuracy: 0.7705
# Epoch 23/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4436 - accuracy: 0.7705
# Epoch 24/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4424 - accuracy: 0.7738
# Epoch 25/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4418 - accuracy: 0.7738
# Epoch 26/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4400 - accuracy: 0.7770
# Epoch 27/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4389 - accuracy: 0.7738
# Epoch 28/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4381 - accuracy: 0.7770
# Epoch 29/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4373 - accuracy: 0.7770
# Epoch 30/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4364 - accuracy: 0.7770
# Epoch 31/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4359 - accuracy: 0.7803
# Epoch 32/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4355 - accuracy: 0.7770
# Epoch 33/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4348 - accuracy: 0.7803
# Epoch 34/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4343 - accuracy: 0.7770
# Epoch 35/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4344 - accuracy: 0.7738
# Epoch 36/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4331 - accuracy: 0.7770
# Epoch 37/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4332 - accuracy: 0.7770
# Epoch 38/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4316 - accuracy: 0.7803
# Epoch 39/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4309 - accuracy: 0.7770
# Epoch 40/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4306 - accuracy: 0.7803
# Epoch 41/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4302 - accuracy: 0.7803
# Epoch 42/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4299 - accuracy: 0.7803
# Epoch 43/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4292 - accuracy: 0.7803
# Epoch 44/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4284 - accuracy: 0.7836
# Epoch 45/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4279 - accuracy: 0.7836
# Epoch 46/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4278 - accuracy: 0.7836
# Epoch 47/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4274 - accuracy: 0.7836
# Epoch 48/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4262 - accuracy: 0.7934
# Epoch 49/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4262 - accuracy: 0.7934
# Epoch 50/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4254 - accuracy: 0.7934
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3679 - accuracy: 0.8026
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 2/9] END .....batch_size=10, epochs=50;, score=0.803 total time=   6.1s
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# 31/31 [==============================] - 1s 3ms/step - loss: 0.6875 - accuracy: 0.6787
# Epoch 2/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6702 - accuracy: 0.6787
# Epoch 3/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6447 - accuracy: 0.6787
# Epoch 4/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6103 - accuracy: 0.6787
# Epoch 5/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5693 - accuracy: 0.6787
# Epoch 6/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5345 - accuracy: 0.6787
# Epoch 7/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5093 - accuracy: 0.6787
# Epoch 8/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4932 - accuracy: 0.6787
# Epoch 9/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4848 - accuracy: 0.6787
# Epoch 10/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4787 - accuracy: 0.6787
# Epoch 11/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4755 - accuracy: 0.6787
# Epoch 12/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4710 - accuracy: 0.6787
# Epoch 13/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4682 - accuracy: 0.6787
# Epoch 14/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4661 - accuracy: 0.6787
# Epoch 15/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4633 - accuracy: 0.6787
# Epoch 16/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4618 - accuracy: 0.6787
# Epoch 17/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4605 - accuracy: 0.6787
# Epoch 18/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4584 - accuracy: 0.6787
# Epoch 19/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4567 - accuracy: 0.7770
# Epoch 20/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4551 - accuracy: 0.8000
# Epoch 21/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4538 - accuracy: 0.8098
# Epoch 22/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4527 - accuracy: 0.8098
# Epoch 23/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4504 - accuracy: 0.8098
# Epoch 24/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4466 - accuracy: 0.8033
# Epoch 25/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4416 - accuracy: 0.8000
# Epoch 26/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.7902
# Epoch 27/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4336 - accuracy: 0.7902
# Epoch 28/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4295 - accuracy: 0.7902
# Epoch 29/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4268 - accuracy: 0.7902
# Epoch 30/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4239 - accuracy: 0.7934
# Epoch 31/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4229 - accuracy: 0.7770
# Epoch 32/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4205 - accuracy: 0.7836
# Epoch 33/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4202 - accuracy: 0.7836
# Epoch 34/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4176 - accuracy: 0.7836
# Epoch 35/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4166 - accuracy: 0.7934
# Epoch 36/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4155 - accuracy: 0.7934
# Epoch 37/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4143 - accuracy: 0.7934
# Epoch 38/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4133 - accuracy: 0.7967
# Epoch 39/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4123 - accuracy: 0.7902
# Epoch 40/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4113 - accuracy: 0.7967
# Epoch 41/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4102 - accuracy: 0.7934
# Epoch 42/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4100 - accuracy: 0.7869
# Epoch 43/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4086 - accuracy: 0.7902
# Epoch 44/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4077 - accuracy: 0.7934
# Epoch 45/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4067 - accuracy: 0.7902
# Epoch 46/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4064 - accuracy: 0.7902
# Epoch 47/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4061 - accuracy: 0.7902
# Epoch 48/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4042 - accuracy: 0.7869
# Epoch 49/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4036 - accuracy: 0.7869
# Epoch 50/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4029 - accuracy: 0.7902
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4840 - accuracy: 0.7500
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 2/9] END .....batch_size=10, epochs=50;, score=0.750 total time=   6.3s
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# Epoch 1/100
# 31/31 [==============================] - 1s 2ms/step - loss: 0.6818 - accuracy: 0.6711
# Epoch 2/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6534 - accuracy: 0.6711
# Epoch 3/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6109 - accuracy: 0.6711
# Epoch 4/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5624 - accuracy: 0.6711
# Epoch 5/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5256 - accuracy: 0.6711
# Epoch 6/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5044 - accuracy: 0.6711
# Epoch 7/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4927 - accuracy: 0.6711
# Epoch 8/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4859 - accuracy: 0.6711
# Epoch 9/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4807 - accuracy: 0.6711
# Epoch 10/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4766 - accuracy: 0.6711
# Epoch 11/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4725 - accuracy: 0.6711
# Epoch 12/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4697 - accuracy: 0.6711
# Epoch 13/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4666 - accuracy: 0.6678
# Epoch 14/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4639 - accuracy: 0.7961
# Epoch 15/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4609 - accuracy: 0.7829
# Epoch 16/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4586 - accuracy: 0.7862
# Epoch 17/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4564 - accuracy: 0.7993
# Epoch 18/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4541 - accuracy: 0.8059
# Epoch 19/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4519 - accuracy: 0.8026
# Epoch 20/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4505 - accuracy: 0.7993
# Epoch 21/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.7993
# Epoch 22/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4468 - accuracy: 0.7993
# Epoch 23/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4451 - accuracy: 0.7993
# Epoch 24/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4438 - accuracy: 0.7993
# Epoch 25/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4424 - accuracy: 0.7993
# Epoch 26/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4408 - accuracy: 0.8026
# Epoch 27/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4389 - accuracy: 0.8026
# Epoch 28/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4375 - accuracy: 0.8026
# Epoch 29/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4361 - accuracy: 0.8026
# Epoch 30/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4346 - accuracy: 0.8059
# Epoch 31/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4333 - accuracy: 0.8092
# Epoch 32/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4318 - accuracy: 0.8059
# Epoch 33/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4313 - accuracy: 0.7993
# Epoch 34/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4285 - accuracy: 0.8059
# Epoch 35/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4272 - accuracy: 0.8092
# Epoch 36/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4259 - accuracy: 0.8059
# Epoch 37/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4246 - accuracy: 0.8059
# Epoch 38/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4233 - accuracy: 0.8092
# Epoch 39/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4218 - accuracy: 0.8158
# Epoch 40/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4213 - accuracy: 0.8125
# Epoch 41/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4192 - accuracy: 0.8158
# Epoch 42/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4181 - accuracy: 0.8191
# Epoch 43/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4169 - accuracy: 0.8158
# Epoch 44/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4156 - accuracy: 0.8125
# Epoch 45/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4145 - accuracy: 0.8158
# Epoch 46/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4143 - accuracy: 0.8158
# Epoch 47/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4124 - accuracy: 0.8191
# Epoch 48/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4107 - accuracy: 0.8191
# Epoch 49/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4098 - accuracy: 0.8224
# Epoch 50/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4086 - accuracy: 0.8191
# Epoch 51/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4073 - accuracy: 0.8191
# Epoch 52/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4058 - accuracy: 0.8224
# Epoch 53/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4045 - accuracy: 0.8224
# Epoch 54/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4038 - accuracy: 0.8289
# Epoch 55/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4023 - accuracy: 0.8289
# Epoch 56/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4011 - accuracy: 0.8322
# Epoch 57/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4007 - accuracy: 0.8388
# Epoch 58/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3992 - accuracy: 0.8355
# Epoch 59/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3986 - accuracy: 0.8322
# Epoch 60/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3968 - accuracy: 0.8322
# Epoch 61/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3958 - accuracy: 0.8355
# Epoch 62/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8388
# Epoch 63/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3932 - accuracy: 0.8388
# Epoch 64/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3922 - accuracy: 0.8355
# Epoch 65/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3916 - accuracy: 0.8355
# Epoch 66/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3906 - accuracy: 0.8421
# Epoch 67/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3894 - accuracy: 0.8421
# Epoch 68/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3882 - accuracy: 0.8421
# Epoch 69/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3883 - accuracy: 0.8388
# Epoch 70/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3861 - accuracy: 0.8421
# Epoch 71/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3856 - accuracy: 0.8421
# Epoch 72/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3839 - accuracy: 0.8454
# Epoch 73/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3833 - accuracy: 0.8421
# Epoch 74/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3838 - accuracy: 0.8421
# Epoch 75/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3816 - accuracy: 0.8454
# Epoch 76/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3803 - accuracy: 0.8454
# Epoch 77/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3788 - accuracy: 0.8454
# Epoch 78/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3790 - accuracy: 0.8421
# Epoch 79/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3785 - accuracy: 0.8487
# Epoch 80/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3762 - accuracy: 0.8520
# Epoch 81/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3765 - accuracy: 0.8454
# Epoch 82/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3752 - accuracy: 0.8487
# Epoch 83/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3733 - accuracy: 0.8487
# Epoch 84/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3721 - accuracy: 0.8487
# Epoch 85/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3717 - accuracy: 0.8520
# Epoch 86/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3711 - accuracy: 0.8487
# Epoch 87/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3694 - accuracy: 0.8454
# Epoch 88/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3685 - accuracy: 0.8454
# Epoch 89/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3677 - accuracy: 0.8487
# Epoch 90/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3670 - accuracy: 0.8487
# Epoch 91/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3666 - accuracy: 0.8487
# Epoch 92/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3654 - accuracy: 0.8520
# Epoch 93/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3648 - accuracy: 0.8454
# Epoch 94/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3642 - accuracy: 0.8553
# Epoch 95/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3637 - accuracy: 0.8520
# Epoch 96/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3616 - accuracy: 0.8553
# Epoch 97/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3613 - accuracy: 0.8520
# Epoch 98/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3605 - accuracy: 0.8520
# Epoch 99/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3594 - accuracy: 0.8520
# Epoch 100/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3593 - accuracy: 0.8553
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4952 - accuracy: 0.7662
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 3/9] END ....batch_size=10, epochs=100;, score=0.766 total time=  11.3s
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# Epoch 1/100
# 31/31 [==============================] - 1s 2ms/step - loss: 0.6807 - accuracy: 0.7016
# Epoch 2/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6570 - accuracy: 0.7049
# Epoch 3/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6259 - accuracy: 0.7049
# Epoch 4/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5856 - accuracy: 0.7049
# Epoch 5/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5447 - accuracy: 0.7049
# Epoch 6/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5074 - accuracy: 0.7049
# Epoch 7/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4787 - accuracy: 0.7475
# Epoch 8/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4577 - accuracy: 0.7836
# Epoch 9/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4414 - accuracy: 0.8000
# Epoch 10/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4291 - accuracy: 0.8131
# Epoch 11/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4188 - accuracy: 0.8131
# Epoch 12/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4106 - accuracy: 0.8164
# Epoch 13/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4044 - accuracy: 0.8197
# Epoch 14/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3982 - accuracy: 0.8197
# Epoch 15/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8197
# Epoch 16/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3894 - accuracy: 0.8230
# Epoch 17/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3862 - accuracy: 0.8295
# Epoch 18/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.8328
# Epoch 19/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3808 - accuracy: 0.8328
# Epoch 20/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3779 - accuracy: 0.8262
# Epoch 21/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3758 - accuracy: 0.8262
# Epoch 22/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3735 - accuracy: 0.8295
# Epoch 23/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3724 - accuracy: 0.8295
# Epoch 24/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3701 - accuracy: 0.8295
# Epoch 25/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3680 - accuracy: 0.8262
# Epoch 26/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3660 - accuracy: 0.8295
# Epoch 27/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3647 - accuracy: 0.8230
# Epoch 28/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3624 - accuracy: 0.8262
# Epoch 29/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3614 - accuracy: 0.8262
# Epoch 30/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3598 - accuracy: 0.8262
# Epoch 31/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3578 - accuracy: 0.8295
# Epoch 32/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3566 - accuracy: 0.8262
# Epoch 33/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3560 - accuracy: 0.8262
# Epoch 34/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3544 - accuracy: 0.8295
# Epoch 35/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3539 - accuracy: 0.8262
# Epoch 36/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3524 - accuracy: 0.8295
# Epoch 37/100
# ...
# Epoch 51/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5615 - accuracy: 0.8131
# Epoch 52/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5597 - accuracy: 0.8131
# Epoch 53/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5580 - accuracy: 0.8131
# Epoch 54/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5564 - accuracy: 0.8098
# Epoch 55/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5550 - accuracy: 0.8066
# Epoch 56/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5529 - accuracy: 0.8033
# Epoch 57/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5519 - accuracy: 0.8066
# Epoch 58/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5500 - accuracy: 0.8098
# Epoch 59/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5484 - accuracy: 0.8098
# Epoch 60/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5468 - accuracy: 0.8066
# Epoch 61/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5454 - accuracy: 0.8000
# Epoch 62/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5439 - accuracy: 0.8066
# Epoch 63/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5425 - accuracy: 0.8098
# Epoch 64/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5411 - accuracy: 0.8098
# Epoch 65/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5395 - accuracy: 0.8066
# Epoch 66/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5381 - accuracy: 0.8066
# Epoch 67/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5367 - accuracy: 0.8066
# Epoch 68/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5354 - accuracy: 0.8098
# Epoch 69/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5339 - accuracy: 0.8098
# Epoch 70/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5325 - accuracy: 0.8098
# Epoch 71/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5313 - accuracy: 0.8066
# Epoch 72/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5299 - accuracy: 0.8066
# Epoch 73/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5285 - accuracy: 0.8098
# Epoch 74/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5272 - accuracy: 0.8098
# Epoch 75/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5260 - accuracy: 0.8098
# Epoch 76/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5248 - accuracy: 0.8098
# Epoch 77/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5236 - accuracy: 0.8098
# Epoch 78/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5223 - accuracy: 0.8066
# Epoch 79/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5211 - accuracy: 0.8098
# Epoch 80/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5197 - accuracy: 0.8098
# Epoch 81/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5184 - accuracy: 0.8098
# Epoch 82/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5173 - accuracy: 0.8066
# Epoch 83/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5160 - accuracy: 0.8066
# Epoch 84/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5153 - accuracy: 0.8066
# Epoch 85/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5138 - accuracy: 0.8098
# Epoch 86/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5125 - accuracy: 0.8098
# Epoch 87/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5112 - accuracy: 0.8098
# Epoch 88/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5103 - accuracy: 0.8098
# Epoch 89/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5090 - accuracy: 0.8098
# Epoch 90/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5080 - accuracy: 0.8098
# Epoch 91/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5069 - accuracy: 0.8098
# Epoch 92/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5056 - accuracy: 0.8098
# Epoch 93/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5047 - accuracy: 0.8098
# Epoch 94/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5038 - accuracy: 0.8098
# Epoch 95/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5025 - accuracy: 0.8131
# Epoch 96/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5015 - accuracy: 0.8131
# Epoch 97/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5005 - accuracy: 0.8131
# Epoch 98/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4994 - accuracy: 0.8131
# Epoch 99/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4982 - accuracy: 0.8131
# Epoch 100/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.8131
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5689 - accuracy: 0.7895
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 9/9] END ....batch_size=40, epochs=100;, score=0.789 total time=   4.6s
# Epoch 1/100
# 39/39 [==============================] - 1s 3ms/step - loss: 0.6800 - accuracy: 0.6903
# Epoch 2/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6491 - accuracy: 0.6798
# Epoch 3/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6088 - accuracy: 0.6798
# Epoch 4/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5648 - accuracy: 0.6798
# Epoch 5/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5222 - accuracy: 0.6772
# Epoch 6/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4935 - accuracy: 0.7087
# Epoch 7/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4763 - accuracy: 0.7690
# Epoch 8/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4652 - accuracy: 0.8031
# Epoch 9/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4579 - accuracy: 0.7822
# Epoch 10/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4507 - accuracy: 0.7769
# Epoch 11/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4456 - accuracy: 0.7769
# Epoch 12/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4416 - accuracy: 0.7822
# Epoch 13/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4367 - accuracy: 0.7822
# Epoch 14/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4325 - accuracy: 0.7795
# Epoch 15/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4292 - accuracy: 0.7822
# Epoch 16/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4254 - accuracy: 0.7822
# Epoch 17/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4226 - accuracy: 0.7848
# Epoch 18/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4210 - accuracy: 0.7848
# Epoch 19/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4191 - accuracy: 0.7848
# Epoch 20/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4164 - accuracy: 0.7874
# Epoch 21/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4144 - accuracy: 0.7927
# Epoch 22/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4128 - accuracy: 0.7927
# Epoch 23/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4113 - accuracy: 0.7874
# Epoch 24/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4096 - accuracy: 0.8031
# Epoch 25/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4088 - accuracy: 0.8058
# Epoch 26/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4063 - accuracy: 0.8058
# Epoch 27/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4047 - accuracy: 0.8084
# Epoch 28/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4035 - accuracy: 0.8058
# Epoch 29/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4021 - accuracy: 0.8084
# Epoch 30/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4007 - accuracy: 0.8084
# Epoch 31/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.8163
# Epoch 32/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3988 - accuracy: 0.8136
# Epoch 33/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3979 - accuracy: 0.8136
# Epoch 34/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3965 - accuracy: 0.8110
# Epoch 35/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3969 - accuracy: 0.8084
# Epoch 36/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.8110
# Epoch 37/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3941 - accuracy: 0.8110
# Epoch 38/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8163
# Epoch 39/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3923 - accuracy: 0.8136
# Epoch 40/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3918 - accuracy: 0.8136
# Epoch 41/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3902 - accuracy: 0.8163
# Epoch 42/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3894 - accuracy: 0.8136
# Epoch 43/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3890 - accuracy: 0.8163
# Epoch 44/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3882 - accuracy: 0.8136
# Epoch 45/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3880 - accuracy: 0.8163
# Epoch 46/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3869 - accuracy: 0.8110
# Epoch 47/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3866 - accuracy: 0.8110
# Epoch 48/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3860 - accuracy: 0.8110
# Epoch 49/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3848 - accuracy: 0.8110
# Epoch 50/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3849 - accuracy: 0.8136
# Epoch 51/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3838 - accuracy: 0.8189
# Epoch 52/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3829 - accuracy: 0.8163
# Epoch 53/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3832 - accuracy: 0.8163
# Epoch 54/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3829 - accuracy: 0.8241
# Epoch 55/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.8136
# Epoch 56/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3812 - accuracy: 0.8084
# Epoch 57/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3804 - accuracy: 0.8215
# Epoch 58/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3797 - accuracy: 0.8241
# Epoch 59/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8215
# Epoch 60/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3786 - accuracy: 0.8268
# Epoch 61/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3786 - accuracy: 0.8136
# Epoch 62/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3789 - accuracy: 0.8268
# Epoch 63/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3778 - accuracy: 0.8294
# Epoch 64/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3777 - accuracy: 0.8215
# Epoch 65/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3783 - accuracy: 0.8189
# Epoch 66/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3761 - accuracy: 0.8268
# Epoch 67/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3771 - accuracy: 0.8241
# Epoch 68/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3766 - accuracy: 0.8215
# Epoch 69/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3747 - accuracy: 0.8294
# Epoch 70/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3751 - accuracy: 0.8241
# Epoch 71/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3752 - accuracy: 0.8241
# Epoch 72/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3746 - accuracy: 0.8346
# Epoch 73/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3752 - accuracy: 0.8189
# Epoch 74/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3737 - accuracy: 0.8294
# Epoch 75/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3728 - accuracy: 0.8294
# Epoch 76/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3725 - accuracy: 0.8294
# Epoch 77/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3721 - accuracy: 0.8320
# Epoch 78/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3718 - accuracy: 0.8241
# Epoch 79/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3715 - accuracy: 0.8294
# Epoch 80/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8294
# Epoch 81/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3705 - accuracy: 0.8294
# Epoch 82/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3699 - accuracy: 0.8294
# Epoch 83/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3695 - accuracy: 0.8294
# Epoch 84/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3688 - accuracy: 0.8294
# Epoch 85/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3683 - accuracy: 0.8294
# Epoch 86/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3685 - accuracy: 0.8215
# Epoch 87/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3685 - accuracy: 0.8268
# Epoch 88/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3671 - accuracy: 0.8320
# Epoch 89/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3668 - accuracy: 0.8268
# Epoch 90/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3666 - accuracy: 0.8294
# Epoch 91/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3659 - accuracy: 0.8294
# Epoch 92/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3646 - accuracy: 0.8268
# Epoch 93/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3648 - accuracy: 0.8294
# Epoch 94/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3649 - accuracy: 0.8320
# Epoch 95/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3633 - accuracy: 0.8294
# Epoch 96/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3637 - accuracy: 0.8268
# Epoch 97/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3633 - accuracy: 0.8294
# Epoch 98/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8294
# Epoch 99/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3616 - accuracy: 0.8294
# Epoch 100/100
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3617 - accuracy: 0.8346
# Best: 0.7637730598449707, using {'batch_size': 10, 'epochs': 100}
# 0.7268626093864441 (0.057903498907772244) with: {'batch_size': 10, 'epochs': 10}
# 0.7532467365264892 (0.06531877759800303) with: {'batch_size': 10, 'epochs': 50}
# 0.7637730598449707 (0.05826547326593186) with: {'batch_size': 10, 'epochs': 100}
# 0.724265205860138 (0.05256747240787551) with: {'batch_size': 20, 'epochs': 10}
# 0.7637730598449707 (0.061728262851570216) with: {'batch_size': 20, 'epochs': 50}
# 0.7559125185012817 (0.07279807561366623) with: {'batch_size': 20, 'epochs': 100}
# 0.7295283675193787 (0.0886237884730712) with: {'batch_size': 40, 'epochs': 10}
# 0.7585099101066589 (0.059263354927033635) with: {'batch_size': 40, 'epochs': 50}
# 0.7585099101066589 (0.06537521599512673) with: {'batch_size': 40, 'epochs': 100}

# %% [markdown]
# **Do a grid search to find the optimal number of neurons in each hidden layer**

# %%
# import necessary packages

# Define a random seed
seed = 6
np.random.seed(seed)

# Start defining the model
def create_model(neuron1, neuron2):
    # create model
    model = Sequential()
    model.add(Dense(neuron1, input_dim = 8, kernel_initializer= 'uniform', activation= 'linear'))
    model.add(Dense(neuron2, input_dim = neuron1, kernel_initializer= 'uniform', activation= 'linear'))
    model.add(Dense(1, activation='sigmoid'))
    
    # compile the model
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
    return model

# create the model
model = KerasClassifier(build_fn = create_model, epochs = 100, batch_size = 20, verbose = 0)

# define the grid search parameters
neuron1 = [4, 8, 16]
neuron2 = [2, 4, 8]

# make a dictionary of the grid search parameters
param_grid = dict(neuron1 = neuron1, neuron2 = neuron2)

# build and fit the GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(random_state=None), refit = True, verbose = 10)
grid_results = grid.fit(X_standardized, Y)

# summarize the results
print("Best: {0}, using {1}".format(grid_results.best_score_, grid_results.best_params_))
means = grid_results.cv_results_['mean_test_score']
stds = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with: {2}'.format(mean, stdev, param))
# Out:
# <ipython-input-22-2d187282a0b0>:21: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model, epochs = 100, batch_size = 20, verbose = 0)
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.831 total time=   4.2s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.684 total time=   3.6s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.816 total time=   4.5s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.868 total time=   6.5s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.789 total time=   3.8s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.831 total time=   4.3s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.671 total time=   6.1s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.816 total time=   4.0s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.868 total time=   6.4s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.789 total time=   6.1s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.831 total time=   3.7s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.671 total time=   6.2s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.816 total time=   4.0s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.868 total time=   6.9s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.789 total time=   6.7s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.831 total time=   3.9s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.671 total time=   6.2s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.816 total time=   6.2s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.868 total time=   6.2s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.789 total time=   3.7s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.818 total time=   4.2s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.671 total time=   3.8s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.816 total time=   3.7s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.868 total time=   6.2s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.789 total time=   3.7s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.831 total time=   7.2s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.671 total time=   6.4s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.816 total time=   4.5s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.868 total time=   6.2s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.789 total time=   6.2s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.831 total time=   3.9s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.671 total time=   3.7s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.816 total time=   6.3s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.868 total time=   3.7s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.789 total time=   6.1s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.831 total time=   3.7s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.671 total time=   3.7s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.816 total time=   7.5s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.868 total time=   6.3s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.789 total time=   6.3s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.831 total time=   4.0s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.671 total time=   4.2s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.816 total time=   6.2s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.868 total time=   6.2s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.789 total time=   6.2s
# Best: 0.7978127241134644, using {'neuron1': 4, 'neuron2': 2}
# 0.7978127241134644 (0.06228375086562368) with: {'neuron1': 4, 'neuron2': 2}
# 0.795181143283844 (0.0671183518745254) with: {'neuron1': 4, 'neuron2': 4}
# 0.795181143283844 (0.0671183518745254) with: {'neuron1': 4, 'neuron2': 8}
# 0.795181143283844 (0.0671183518745254) with: {'neuron1': 8, 'neuron2': 2}
# 0.7925837397575378 (0.06591593197289686) with: {'neuron1': 8, 'neuron2': 4}
# 0.795181143283844 (0.0671183518745254) with: {'neuron1': 8, 'neuron2': 8}
# 0.795181143283844 (0.0671183518745254) with: {'neuron1': 16, 'neuron2': 2}
# 0.795181143283844 (0.0671183518745254) with: {'neuron1': 16, 'neuron2': 4}
# 0.795181143283844 (0.0671183518745254) with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# **Generate predictions with optimal hyperparameters**

# %%
y_pred = grid.predict(X_standardized)
# Out:
# 12/12 [==============================] - 0s 2ms/step

# %%
print(y_pred.shape)
# Out:
# (381, 1)

# %%
print(y_pred[:5])
# Out:
# [[0]
#  [0]
#  [0]
#  [1]
#  [0]]

# %% [markdown]
# <h2>Generate a classification report</h2>

# %%
from sklearn.metrics import classification_report, accuracy_score

print(accuracy_score(Y, y_pred))
print(classification_report(Y, y_pred))
# Out:
# 0.7926509186351706
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.86       259
#            1       0.73      0.57      0.64       122
#
#     accuracy                           0.79       381
#    macro avg       0.77      0.73      0.75       381
# weighted avg       0.79      0.79      0.78       381

# %% [markdown]
#  # <font color='green'>Please do the following: Take the example and find a dataset that can apply the same process
#  </font>
